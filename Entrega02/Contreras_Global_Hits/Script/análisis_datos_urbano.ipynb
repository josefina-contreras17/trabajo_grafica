# %%
# ==============================================================================
# SCRIPT DE CARGA Y VISUALIZACIÓN DE DATOS (PANDAS)
# Proyecto: Anatomía de un "Hit" Regional vs. Global (Enfoque Chile)
# ==============================================================================

# Importar la librería Pandas, fundamental para la manipulación de datos en Python
import pandas as pd

# 1. Definir la ruta del archivo limpio
# Nota: El archivo debe estar subido al entorno de archivos temporales de Colab.
nombre_archivo = 'identificacion_parametros_datasetESTESI.csv'

# 2. Cargar el CSV en un DataFrame de Pandas
# Se utiliza el parámetro de codificación para respetar tildes y caracteres especiales del español
try:
    df_hits = pd.read_csv(nombre_archivo, encoding='utf-8-sig', sep=';')
    print("✅ Base de datos cargada exitosamente en el DataFrame 'df_hits'.")
    print(f"📊 Total de registros: {len(df_hits)} canciones.\n")
except FileNotFoundError:
    print("❌ Error: No se encontró el archivo. Asegúrate de haberlo subido a la pestaña de Archivos en Colab.")

# 3. Visualizar las primeras 5 filas de la base de datos limpia
# La función .head() muestra por defecto los primeros 5 registros del DataFrame
df_hits.head()
# Out:
# ✅ Base de datos cargada exitosamente en el DataFrame 'df_hits'.
# 📊 Total de registros: 1048575 canciones.
# /tmp/ipykernel_29031/3271662412.py:16: DtypeWarning: Columns (0,1,2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_hits = pd.read_csv(nombre_archivo, encoding='utf-8-sig', sep=';')
#                           Nombre canción                   Artista  \
# 0              Unholy (feat. Kim Petras)     Sam Smith, Kim Petras
# 1  Quevedo: Bzrp Music Sessions, Vol. 52         Bizarrap, Quevedo
# 2                             La Bachata             Manuel Turizo
# 3                        I'm Good (Blue)  David Guetta, Bebe Rexha
# 4                       Tití Me Preguntó                 Bad Bunny
#
#   ¿Es chileno? (sí/no) Fecha de lanzamiento  Duración (segundos)  \
# 0                   No        No disponible                157.0
# 1                   No        No disponible                199.0
# ...
