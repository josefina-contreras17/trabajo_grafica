# %% [markdown]
# # Visualizaciones

# %%
import pandas as pd
import altair as alt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bb2b14a4-1447-41d2-bab3-27be28c2e2d5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb2b14a4-1447-41d2-bab3-27be28c2e2d5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("mejorescancionesderock UTF (1).csv")

# %%
display(df.head())
# Out:
#                               Track URI                         Track Name  \
# 0  spotify:track:5E8fsTZfvnj7tuRvCnV4SV  Todos Juntos - 2020 Remasterizado
# 1  spotify:track:15T3otpUnJKin5njR8x0Tx         El Baile De Los Que Sobran
# 2  spotify:track:1xtBatmC1muBOY1RnUvP8Z                        Déjate Caer
# 3  spotify:track:6hgHu5Cj3fFGMl8DPtZdWS           Baño De Mar A Medianoche
# 4  spotify:track:6As9jWGwGowXeSd2OiQzeg                               Miño
#
#                         Album Name   Artist Name(s) Release Date  \
# 0  La Ventana (2020 Remasterizado)       Los Jaivas   1973-01-01
# 1                 Pateando Piedras  Los Prisioneros   1986-01-01
# 2             La Espada & la Pared         Los Tres         1995
# 3                  La Incomparable          Cecilia   2006-01-01
# 4                 Canción De Lejos      Los Bunkers         2002
#
#    Duration (ms)  Popularity  Explicit     Added By              Added At  \
# ...

# %%
df
# Out:
#                                 Track URI  \
# 0    spotify:track:5E8fsTZfvnj7tuRvCnV4SV
# 1    spotify:track:15T3otpUnJKin5njR8x0Tx
# 2    spotify:track:1xtBatmC1muBOY1RnUvP8Z
# 3    spotify:track:6hgHu5Cj3fFGMl8DPtZdWS
# 4    spotify:track:6As9jWGwGowXeSd2OiQzeg
# ..                                    ...
# 227  spotify:track:4YdzIFRNNztAB1JF4AltPZ
# 228  spotify:track:1fwyd3uffoIUVw5FNoWaZg
# 229  spotify:track:1j0jAzxLglyMQaA4C3oqZs
# 230  spotify:track:3Yt7vScNXj7VtWeH8Ras00
# 231  spotify:track:7EdwoFIHkKb5hW2hKMJYri
#
#                                         Track Name  \
# 0                Todos Juntos - 2020 Remasterizado
# 1                       El Baile De Los Que Sobran
# 2                                      Déjate Caer
# 3                         Baño De Mar A Medianoche
# 4                                             Miño
# ..                                             ...
# 227                        Ella Llora - Remastered
# ...

# %%
df.columns = df.columns.str.strip()

# %%
alt.Chart(df).mark_bar(color="teal").encode(
    x="Track Name:N",
    y="Popularity:Q",
)
# Out:
# alt.Chart(...)

# %%
select = alt.selection_point(name="select", on="click")
highlight = alt.selection_point(name="highlight", on="pointerover", empty=False)

# %%
import altair as alt

source_filename = "mejorescancionesderock UTF (1).csv"

alt.Chart(df).mark_bar(
    cornerRadiusTopLeft=3,
    cornerRadiusTopRight=3
).encode(
    x='month(Release Date):O',
    y='count():Q',
    color='Artist Name(s):N'
)
# Out:
# alt.Chart(...)

# %%
select = alt.selection_point(name="select", on="click")
highlight = alt.selection_point(name="highlight", on="pointerover", empty=False)

# %%
# !jupyter nbconvert --to html "Visualizaciones.ipynb"
# Out:
# [NbConvertApp] Converting notebook Visualizaciones.ipynb to html
# [NbConvertApp] Writing 1042451 bytes to Visualizaciones.html
